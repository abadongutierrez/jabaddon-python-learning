# %%
# Uninstall and reinstall numpy with correct architecture
# !pip uninstall numpy -y
# !pip install --no-cache-dir --force-reinstall numpy

# Install other packages
# !pip install --upgrade pip
# !pip install ibm-watsonx-ai
# !pip install langchain
# !pip install langchain-ibm
# Out:
# WARNING: Skipping numpy as it is not installed.
# Collecting numpy
# Collecting numpy
#   Downloading numpy-2.3.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
#   Downloading numpy-2.3.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Downloading numpy-2.3.3-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/5.1 MB ? eta -:--:--Downloading numpy-2.3.3-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 15.0 MB/s eta 0:00:00 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 15.0 MB/s eta 0:00:00
# Installing collected packages: numpy
# Installing collected packages: numpy
# Successfully installed numpy-2.3.3
# Successfully installed numpy-2.3.3
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pip in ./myenv/lib/python3.13/site-packages (25.1.1)
# Requirement already satisfied: pip in ./myenv/lib/python3.13/site-packages (25.1.1)
# Collecting pip
#   Using cached pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.2-py3-none-any.whl (1.8 MB)
# Collecting pip
#   Using cached pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.2-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# Successfully installed pip-25.2
# Successfully installed pip-25.2
# Collecting ibm-watsonx-ai
#   Using cached ibm_watsonx_ai-1.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting ibm-watsonx-ai
#   Using cached ibm_watsonx_ai-1.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting requests (from ibm-watsonx-ai)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting requests (from ibm-watsonx-ai)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting httpx<0.29,>=0.27 (from ibm-watsonx-ai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx<0.29,>=0.27 (from ibm-watsonx-ai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting urllib3 (from ibm-watsonx-ai)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting urllib3 (from ibm-watsonx-ai)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pandas<2.3.0,>=0.24.2 (from ibm-watsonx-ai)
#   Using cached pandas-2.2.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting pandas<2.3.0,>=0.24.2 (from ibm-watsonx-ai)
#   Using cached pandas-2.2.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting certifi (from ibm-watsonx-ai)
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting certifi (from ibm-watsonx-ai)
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting lomond (from ibm-watsonx-ai)
#   Using cached lomond-0.3.3-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting lomond (from ibm-watsonx-ai)
#   Using cached lomond-0.3.3-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting tabulate (from ibm-watsonx-ai)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting tabulate (from ibm-watsonx-ai)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting packaging (from ibm-watsonx-ai)
# Collecting packaging (from ibm-watsonx-ai)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting ibm-cos-sdk<2.15.0,>=2.12.0 (from ibm-watsonx-ai)
#   Using cached ibm_cos_sdk-2.14.3-py3-none-any.whl
# Collecting ibm-cos-sdk<2.15.0,>=2.12.0 (from ibm-watsonx-ai)
#   Using cached ibm_cos_sdk-2.14.3-py3-none-any.whl
# Collecting cachetools (from ibm-watsonx-ai)
#   Using cached cachetools-6.2.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting cachetools (from ibm-watsonx-ai)
#   Using cached cachetools-6.2.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting anyio (from httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting anyio (from httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting httpcore==1.* (from httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting httpcore==1.* (from httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting idna (from httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting ibm-cos-sdk-core==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Using cached ibm_cos_sdk_core-2.14.3-py3-none-any.whl
# Collecting ibm-cos-sdk-core==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Using cached ibm_cos_sdk_core-2.14.3-py3-none-any.whl
# Collecting ibm-cos-sdk-s3transfer==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Using cached ibm_cos_sdk_s3transfer-2.14.3-py3-none-any.whl
# Collecting ibm-cos-sdk-s3transfer==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Using cached ibm_cos_sdk_s3transfer-2.14.3-py3-none-any.whl
# Collecting jmespath<=1.0.1,>=0.10.0 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting jmespath<=1.0.1,>=0.10.0 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting python-dateutil<3.0.0,>=2.9.0 (from ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.26.0 in ./myenv/lib/python3.13/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai) (2.3.3)
# Collecting python-dateutil<3.0.0,>=2.9.0 (from ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.26.0 in ./myenv/lib/python3.13/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai) (2.3.3)
# Collecting pytz>=2020.1 (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting pytz>=2020.1 (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting tzdata>=2022.7 (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil<3.0.0,>=2.9.0->ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting six>=1.5 (from python-dateutil<3.0.0,>=2.9.0->ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests->ibm-watsonx-ai)
#   Using cached charset_normalizer-3.4.3-cp313-cp313-macosx_10_13_universal2.whl.metadata (36 kB)
# Collecting charset_normalizer<4,>=2 (from requests->ibm-watsonx-ai)
#   Using cached charset_normalizer-3.4.3-cp313-cp313-macosx_10_13_universal2.whl.metadata (36 kB)
# Collecting sniffio>=1.1 (from anyio->httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached ibm_watsonx_ai-1.4.0-py3-none-any.whl (1.1 MB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached pandas-2.2.3-cp313-cp313-macosx_11_0_arm64.whl (11.3 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.3-cp313-cp313-macosx_10_13_universal2.whl (205 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting sniffio>=1.1 (from anyio->httpx<0.29,>=0.27->ibm-watsonx-ai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached ibm_watsonx_ai-1.4.0-py3-none-any.whl (1.1 MB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached pandas-2.2.3-cp313-cp313-macosx_11_0_arm64.whl (11.3 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.3-cp313-cp313-macosx_10_13_universal2.whl (205 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached cachetools-6.2.1-py3-none-any.whl (11 kB)
# Using cached lomond-0.3.3-py2.py3-none-any.whl (35 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached cachetools-6.2.1-py3-none-any.whl (11 kB)
# Using cached lomond-0.3.3-py2.py3-none-any.whl (35 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: pytz, urllib3, tzdata, tabulate, sniffio, six, packaging, jmespath, idna, h11, charset_normalizer, certifi, cachetools, requests, python-dateutil, lomond, httpcore, anyio, pandas, ibm-cos-sdk-core, httpx, ibm-cos-sdk-s3transfer, ibm-cos-sdk, ibm-watsonx-ai
# Installing collected packages: pytz, urllib3, tzdata, tabulate, sniffio, six, packaging, jmespath, idna, h11, charset_normalizer, certifi, cachetools, requests, python-dateutil, lomond, httpcore, anyio, pandas, ibm-cos-sdk-core, httpx, ibm-cos-sdk-s3transfer, ibm-cos-sdk, ibm-watsonx-ai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [ibm-watsonx-ai]23/24 [ibm-watsonx-ai]sdk]core]
# Successfully installed anyio-4.11.0 cachetools-6.2.1 certifi-2025.10.5 charset_normalizer-3.4.3 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 ibm-cos-sdk-2.14.3 ibm-cos-sdk-core-2.14.3 ibm-cos-sdk-s3transfer-2.14.3 ibm-watsonx-ai-1.4.0 idna-3.11 jmespath-1.0.1 lomond-0.3.3 packaging-25.0 pandas-2.2.3 python-dateutil-2.9.0.post0 pytz-2025.2 requests-2.32.5 six-1.17.0 sniffio-1.3.1 tabulate-0.9.0 tzdata-2025.2 urllib3-2.5.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [ibm-watsonx-ai]
# Successfully installed anyio-4.11.0 cachetools-6.2.1 certifi-2025.10.5 charset_normalizer-3.4.3 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 ibm-cos-sdk-2.14.3 ibm-cos-sdk-core-2.14.3 ibm-cos-sdk-s3transfer-2.14.3 ibm-watsonx-ai-1.4.0 idna-3.11 jmespath-1.0.1 lomond-0.3.3 packaging-25.0 pandas-2.2.3 python-dateutil-2.9.0.post0 pytz-2025.2 requests-2.32.5 six-1.17.0 sniffio-1.3.1 tabulate-0.9.0 tzdata-2025.2 urllib3-2.5.0
# Collecting langchain
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain)
#   Using cached langchain_core-0.3.79-py3-none-any.whl.metadata (3.2 kB)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain)
#   Using cached langchain_core-0.3.79-py3-none-any.whl.metadata (3.2 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Using cached langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
#   Using cached langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Using cached langsmith-0.4.34-py3-none-any.whl.metadata (14 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Using cached langsmith-0.4.34-py3-none-any.whl.metadata (14 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.12.1-py3-none-any.whl.metadata (85 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.12.1-py3-none-any.whl.metadata (85 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Using cached sqlalchemy-2.0.44-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Using cached sqlalchemy-2.0.44-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Requirement already satisfied: requests<3,>=2 in ./myenv/lib/python3.13/site-packages (from langchain) (2.32.5)
# Requirement already satisfied: requests<3,>=2 in ./myenv/lib/python3.13/site-packages (from langchain) (2.32.5)
# Collecting PyYAML>=5.3 (from langchain)
# Collecting PyYAML>=5.3 (from langchain)
#   Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
#   Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./myenv/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./myenv/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Using cached orjson-3.11.3-cp313-cp313-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Using cached orjson-3.11.3-cp313-cp313-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Using cached zstandard-0.25.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.11.0)
# Requirement already satisfied: certifi in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in ./myenv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Collecting zstandard>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Using cached zstandard-0.25.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.11.0)
# Requirement already satisfied: certifi in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in ./myenv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in ./myenv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.3 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached pydantic_core-2.41.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting pydantic-core==2.41.3 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached pydantic_core-2.41.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./myenv/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./myenv/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in ./myenv/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./myenv/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./myenv/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in ./myenv/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.79-py3-none-any.whl (449 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Using cached langsmith-0.4.34-py3-none-any.whl (386 kB)
# Using cached pydantic-2.12.1-py3-none-any.whl (460 kB)
# Using cached pydantic_core-2.41.3-cp313-cp313-macosx_11_0_arm64.whl (1.9 MB)
# Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Using cached sqlalchemy-2.0.44-cp313-cp313-macosx_11_0_arm64.whl (2.1 MB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached orjson-3.11.3-cp313-cp313-macosx_15_0_arm64.whl (127 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached zstandard-0.25.0-cp313-cp313-macosx_11_0_arm64.whl (640 kB)
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.79-py3-none-any.whl (449 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Using cached langsmith-0.4.34-py3-none-any.whl (386 kB)
# Using cached pydantic-2.12.1-py3-none-any.whl (460 kB)
# Using cached pydantic_core-2.41.3-cp313-cp313-macosx_11_0_arm64.whl (1.9 MB)
# Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Using cached sqlalchemy-2.0.44-cp313-cp313-macosx_11_0_arm64.whl (2.1 MB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached orjson-3.11.3-cp313-cp313-macosx_15_0_arm64.whl (127 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached zstandard-0.25.0-cp313-cp313-macosx_11_0_arm64.whl (640 kB)
# Installing collected packages: zstandard, typing-extensions, tenacity, PyYAML, orjson, jsonpointer, annotated-types, typing-inspection, SQLAlchemy, requests-toolbelt, pydantic-core, jsonpatch, pydantic, langsmith, langchain-core, langchain-text-splitters, langchain
# Installing collected packages: zstandard, typing-extensions, tenacity, PyYAML, orjson, jsonpointer, annotated-types, typing-inspection, SQLAlchemy, requests-toolbelt, pydantic-core, jsonpatch, pydantic, langsmith, langchain-core, langchain-text-splitters, langchain
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [langchain]237m━━ 16/17 [langchain]litters]
# Successfully installed PyYAML-6.0.3 SQLAlchemy-2.0.44 annotated-types-0.7.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.27 langchain-core-0.3.79 langchain-text-splitters-0.3.11 langsmith-0.4.34 orjson-3.11.3 pydantic-2.12.1 pydantic-core-2.41.3 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-extensions-4.15.0 typing-inspection-0.4.2 zstandard-0.25.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [langchain]
# Successfully installed PyYAML-6.0.3 SQLAlchemy-2.0.44 annotated-types-0.7.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.27 langchain-core-0.3.79 langchain-text-splitters-0.3.11 langsmith-0.4.34 orjson-3.11.3 pydantic-2.12.1 pydantic-core-2.41.3 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-extensions-4.15.0 typing-inspection-0.4.2 zstandard-0.25.0
# Collecting langchain-ibm
#   Using cached langchain_ibm-0.3.18-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: ibm-watsonx-ai<2.0.0,>=1.3.37 in ./myenv/lib/python3.13/site-packages (from langchain-ibm) (1.4.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.39 in ./myenv/lib/python3.13/site-packages (from langchain-ibm) (0.3.79)
# Requirement already satisfied: requests in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.32.5)
# Requirement already satisfied: httpx<0.29,>=0.27 in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (0.28.1)
# Requirement already satisfied: urllib3 in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.5.0)
# Requirement already satisfied: pandas<2.3.0,>=0.24.2 in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.2.3)
# Requirement already satisfied: certifi in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2025.10.5)
# Requirement already satisfied: lomond in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (0.3.3)
# Requirement already satisfied: tabulate in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (0.9.0)
# Requirement already satisfied: packaging in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (25.0)
# Requirement already satisfied: ibm-cos-sdk<2.15.0,>=2.12.0 in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.14.3)
# Requirement already satisfied: cachetools in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (6.2.1)
# Requirement already satisfied: anyio in ./myenv/lib/python3.13/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (4.11.0)
# Requirement already satisfied: httpcore==1.* in ./myenv/lib/python3.13/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (1.0.9)
# Requirement already satisfied: idna in ./myenv/lib/python3.13/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (3.11)
# Requirement already satisfied: h11>=0.16 in ./myenv/lib/python3.13/site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (0.16.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.14.3 in ./myenv/lib/python3.13/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.14.3)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.14.3 in ./myenv/lib/python3.13/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.14.3)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in ./myenv/lib/python3.13/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in ./myenv/lib/python3.13/site-packages (from ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.9.0.post0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (0.4.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (4.15.0)
# Collecting langchain-ibm
#   Using cached langchain_ibm-0.3.18-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: ibm-watsonx-ai<2.0.0,>=1.3.37 in ./myenv/lib/python3.13/site-packages (from langchain-ibm) (1.4.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.39 in ./myenv/lib/python3.13/site-packages (from langchain-ibm) (0.3.79)
# Requirement already satisfied: requests in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.32.5)
# Requirement already satisfied: httpx<0.29,>=0.27 in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (0.28.1)
# Requirement already satisfied: urllib3 in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.5.0)
# Requirement already satisfied: pandas<2.3.0,>=0.24.2 in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.2.3)
# Requirement already satisfied: certifi in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2025.10.5)
# Requirement already satisfied: lomond in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (0.3.3)
# Requirement already satisfied: tabulate in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (0.9.0)
# Requirement already satisfied: packaging in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (25.0)
# Requirement already satisfied: ibm-cos-sdk<2.15.0,>=2.12.0 in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.14.3)
# Requirement already satisfied: cachetools in ./myenv/lib/python3.13/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (6.2.1)
# Requirement already satisfied: anyio in ./myenv/lib/python3.13/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (4.11.0)
# Requirement already satisfied: httpcore==1.* in ./myenv/lib/python3.13/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (1.0.9)
# Requirement already satisfied: idna in ./myenv/lib/python3.13/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (3.11)
# Requirement already satisfied: h11>=0.16 in ./myenv/lib/python3.13/site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (0.16.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.14.3 in ./myenv/lib/python3.13/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.14.3)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.14.3 in ./myenv/lib/python3.13/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.14.3)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in ./myenv/lib/python3.13/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in ./myenv/lib/python3.13/site-packages (from ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.9.0.post0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (0.4.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (4.15.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (2.12.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./myenv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (0.25.0)
# Requirement already satisfied: numpy>=1.26.0 in ./myenv/lib/python3.13/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in ./myenv/lib/python3.13/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./myenv/lib/python3.13/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.3 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (2.41.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (0.4.2)
# Requirement already satisfied: six>=1.5 in ./myenv/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.9.0->ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./myenv/lib/python3.13/site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (3.4.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./myenv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain-ibm) (2.12.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./myenv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./myenv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (0.25.0)
# Requirement already satisfied: numpy>=1.26.0 in ./myenv/lib/python3.13/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in ./myenv/lib/python3.13/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./myenv/lib/python3.13/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.3 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (2.41.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./myenv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.39->langchain-ibm) (0.4.2)
# Requirement already satisfied: six>=1.5 in ./myenv/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.9.0->ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./myenv/lib/python3.13/site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (3.4.3)
# Requirement already satisfied: sniffio>=1.1 in ./myenv/lib/python3.13/site-packages (from anyio->httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (1.3.1)
# Using cached langchain_ibm-0.3.18-py3-none-any.whl (41 kB)
# Requirement already satisfied: sniffio>=1.1 in ./myenv/lib/python3.13/site-packages (from anyio->httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain-ibm) (1.3.1)
# Using cached langchain_ibm-0.3.18-py3-none-any.whl (41 kB)
# Installing collected packages: langchain-ibm
# Installing collected packages: langchain-ibm
# Successfully installed langchain-ibm-0.3.18
# Successfully installed langchain-ibm-0.3.18

# %%
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

from ibm_watsonx_ai.foundation_models import Model
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
from langchain_ibm import WatsonxLLM
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain

# %% [markdown]
# ### Setup LLM
#
# In this section, you will build an LLM model from IBM watsonx.ai.
#
# The following code initializes a IBM Granite model on IBM's watsonx.ai platform and wraps it into a function that could allow repeat use.
#
# Some key parameters are explained here:
# - `model_id` specifies which model you want to use. There are various model options available; refer to the [Foundation Models](https://ibm.github.io/watsonx-ai-python-sdk/foundation_models.html) documentation for more options. In this tutorial, you'll use the `ibm/granite-3-2-8b-instruct` model.
# - `parameters` define the model's configuration. Set five commonly used parameters for this tutorial. To explore additional commonly used parameters, you can run the code `GenParams().get_example_values()` to see. If no custom parameters are passed to the function, the model will use `default_params`.
# - `credentials` and `project_id` are necessary parameters to successfully run LLMs from watsonx.ai. (Keep `credentials` and `project_id` as they are now so that you do not need to create your own keys to run models. This supports you in running the model inside this lab environment. However, if you want to run the model locally, refer to this [tutorial](https://medium.com/the-power-of-ai/ibm-watsonx-ai-the-interface-and-api-e8e1c7227358) for creating your own keys.
# - `Model()` is used to wrap the parameters for the model and then call it with `WatsonxLLM()`.

# %%
def llm_model(prompt_txt, params=None):
    model_id = 'ibm/granite-3-2-8b-instruct'

    default_params = {
        "max_new_tokens": 256,
        "min_new_tokens": 0,
        "temperature": 0.5,
        "top_p": 0.2,
        "top_k": 1
    }

    if params:
        default_params.update(params)

    parameters = {
        GenParams.MAX_NEW_TOKENS: default_params["max_new_tokens"],  # this controls the maximum number of tokens in the generated output
        GenParams.MIN_NEW_TOKENS: default_params["min_new_tokens"], # this controls the minimum number of tokens in the generated output
        GenParams.TEMPERATURE: default_params["temperature"], # this randomness or creativity of the model's responses
        GenParams.TOP_P: default_params["top_p"],
        GenParams.TOP_K: default_params["top_k"]
    }
    
    credentials = {
        "url": "https://us-south.ml.cloud.ibm.com"
    }
    
    project_id = "skills-network"
    
    model = Model(
        model_id=model_id,
        params=parameters,
        credentials=credentials,
        project_id=project_id
    )
    
    mixtral_llm = WatsonxLLM(model=model)
    response  = mixtral_llm.invoke(prompt_txt)
    return response

# %%
GenParams().get_example_values()
# Out:
# {'decoding_method': 'sample',
#  'length_penalty': {'decay_factor': 2.5, 'start_index': 5},
#  'temperature': 0.5,
#  'top_p': 0.2,
#  'top_k': 1,
#  'random_seed': 33,
#  'repetition_penalty': 2,
#  'min_new_tokens': 50,
#  'max_new_tokens': 200,
#  'stop_sequences': ['fail'],
#  'time_limit': 600000,
#  'truncate_input_tokens': 200,
#  'prompt_variables': {'object': 'brain'},
#  'return_options': {'input_text': True,
#   'generated_tokens': True,
#   'input_tokens': True,
#   'token_logprobs': True,
#   'token_ranks': False,
#   'top_n_tokens': False}}

# %% [markdown]
# ## Prompt engineering
#
# ### First basic promp
#
# In this example, let's introduce a basic prompt that utilizes specific parameters to guide the language model's response. You'll then define a simple prompt and retrieve the model's response,
#
# The prompt used is "The wind is". Let the model generate itself.

# %%
params = {
    "max_new_tokens": 128,
    "min_new_tokens": 10,
    "temperature": 0.5,
    "top_p": 0.2,
    "top_k": 1
}

prompt = "The wind is"

response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[8], line 11
#       1 params = {
#       2     "max_new_tokens": 128,
#       3     "min_new_tokens": 10,
#    (...)      6     "top_k": 1
#       7 }
#       9 prompt = "The wind is"
# ---> 11 response = llm_model(prompt, params)
#      12 print(f"prompt: {prompt}\n")
#      13 print(f"response : {response}\n")
#
# Cell In[6], line 29, in llm_model(prompt_txt, params)
#      23 credentials = {
#      24     "url": "https://us-south.ml.cloud.ibm.com"
#      25 }
#      27 project_id = "skills-network"
# ---> 29 model = Model(
#      30     model_id=model_id,
#      31     params=parameters,
#      32     credentials=credentials,
#      33     project_id=project_id
#      34 )
#      36 mixtral_llm = WatsonxLLM(model=model)
#      37 response  = mixtral_llm.invoke(prompt_txt)
#
# File ~/Projects/JAbaddon/Repositories/jabaddon-python-learning/practice_projects/in-context-eng-prompt-templates/myenv/lib/python3.13/site-packages/ibm_watsonx_ai/foundation_models/model.py:108, in Model.__init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#     101     model_class_deprecated_warning = (
#     102         "The `Model` class is deprecated and will be removed in a future release. "
#     103         "Please use the `ModelInference` class instead. "
#     104         "To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`."
#     105     )
#     106     warn(model_class_deprecated_warning, category=DeprecationWarning)
# --> 108 ModelInference.__init__(
#     109     self,
#     110     model_id=model_id,
#     111     credentials=credentials,
#     112     params=params,
#     113     project_id=project_id,
#     114     space_id=space_id,
#     115     verify=verify,
#     116     validate=validate,
#     117 )
#
# File ~/Projects/JAbaddon/Repositories/jabaddon-python-learning/practice_projects/in-context-eng-prompt-templates/myenv/lib/python3.13/site-packages/ibm_watsonx_ai/foundation_models/inference/model_inference.py:189, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, persistent_connection, max_retries, delay_time, retry_status_codes)
#     186 if credentials:
#     187     from ibm_watsonx_ai import APIClient
# --> 189     self.set_api_client(APIClient(credentials, verify=verify))
#     190 elif api_client:
#     191     self.set_api_client(api_client)
#
# File ~/Projects/JAbaddon/Repositories/jabaddon-python-learning/practice_projects/in-context-eng-prompt-templates/myenv/lib/python3.13/site-packages/ibm_watsonx_ai/client.py:374, in APIClient.__init__(self, credentials, project_id, space_id, verify, httpx_client, async_httpx_client, **kwargs)
#     369         raise WMLClientError(
#     370             Messages.get_message(message_id="invalid_url_provided")
#     371         )
#     373     if not self._is_IAM():
# --> 374         raise WMLClientError(
#     375             Messages.get_message(message_id="apikey_not_provided")
#     376         )
#     377 else:
#     378     self.CLOUD_PLATFORM_SPACES = False
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'
